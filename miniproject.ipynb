# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_url='https://raw.githubusercontent.com/datastray/python_project/main/sales_data.csv'
df = pd.read_csv(data_url)


df.head()
# Out:
#    transaction_ID        date product_category             product_name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    units_sold  unit_price  total_revenue       location
# 0           2      999.99        1999.98  North America
# 1           1      499.99         499.99         Europe
# 2           3       69.99         209.97           Asia
# 3           4       15.99          63.96  North America
# 4           1       89.99          89.99         Europe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_ID    245 non-null    int64
#  1   date              245 non-null    object
#  2   product_category  245 non-null    object
#  3   product_name      245 non-null    object
#  4   units_sold        245 non-null    int64
#  5   unit_price        245 non-null    float64
#  6   total_revenue     245 non-null    float64
#  7   location          245 non-null    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 15.4+ KB

# %%
product_category_revenue=df.groupby('product_category')['total_revenue'].sum()

total_revenue=df['total_revenue'].sum()
product_category_percentage=product_category_revenue/total_revenue*100
product_category_percentage
# Out:
# product_category
# Beauty Products     3.142380
# Books               2.231546
# Clothing            9.742623
# Electronics        45.365287
# Home Appliances    22.347653
# Sports             17.170511
# Name: total_revenue, dtype: float64

# %%
product_category_percentage.plot(kind='bar')
plt.title('Percentage of total revenue by product category')
plt.ylabel('Percentage (%)')
plt.show()

# %%
product_location_revenue=df.groupby(['product_category','location'])['total_revenue'].sum()
product_location_revenue
# Out:
# product_category  location
# Beauty Products   Europe            2621.90
# Books             North America     1861.93
# Clothing          Asia              8128.93
# Electronics       Asia              1868.94
#                   Europe             999.98
#                   North America    34982.41
# Home Appliances   Europe           18646.16
# Sports            Asia             14326.52
# Name: total_revenue, dtype: float64
